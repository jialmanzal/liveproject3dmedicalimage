# %% [markdown]
# ## Training and Validation Data Setup

# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy import ndimage

# %%
imagen_t1 = nib.load('IXI016-Guys-0697-T1.nii.gz')
imagen_t2 = nib.load('IXI016-Guys-0697-T2.nii.gz')
image_data_t1 = imagen_t1.get_fdata()
image_data_t2 = imagen_t2.get_fdata()

print('la imagen imagen_t1 tiene la forma {}'.format(image_data_t1.shape))
print('la imagen imagen_t2 tiene la forma {}'.format(image_data_t2.shape))
# Out:
# la imagen imagen_t1 tiene la forma (256, 256, 150)
# la imagen imagen_t2 tiene la forma (256, 256, 120)

# %% [markdown]
# 1. *Se visualiza imagen_t1*

# %%
plt.figure(figsize=(10,10), dpi=80)

#plt.imshow(image_data_t1[75], aspect=0.5)

plt.imshow(image_data_t1[:,145,:], cmap=plt.cm.gray)

# %% [markdown]
# 2. *Se visualiza imagen_t2*

# %%
plt.figure(figsize=(10,10), dpi=80)
plt.imshow(image_data_t2[:,:,40], cmap=plt.cm.gray)

# %% [markdown]
# rotate_lena_noreshape = ndimage.rotate(image_data_t2, 45, reshape=False)
